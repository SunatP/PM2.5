# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import json
import pandas as pd
from datetime import timedelta, date
from tqdm import tqdm

start_date = date(2019, 1, 1)
end_date = date(2019, 10, 1)

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def daterange(start_date, end_date):
    for n in tqdm(range(int ((end_date - start_date).days))):
        yield start_date + timedelta(n)

write_header = 1
write_header_file = 1 # change to 0 to continue without writing header to csv
for single_date in daterange(start_date, end_date):
    df_daily = pd.DataFrame()
    ymd = single_date.strftime("%Y%m%d")
    url_test = "https://api-ak.wunderground.com/api/606f3f6977348613/history_"+ymd+"null/units:metric/v:2.0/q/pws:IKAMPHAE2.json"
#     url_test ="http://api.wunderground.com/api/91b595b129984cc5b595b12998bcc57f/history/q/TH/IBANGY1.json"
    req = requests.get(url_test)
    js = json.loads(req.text)
    if js['history']['days'] == []:
        print("empty data on",ymd)
        continue
    for ob in js['history']['days'][0]['observations']:
        ob['date'] = ob['date']['iso8601']
        df_row = pd.DataFrame(ob, index=[0]) 
        df_row.index = df_row['date']
        df_row = df_row.drop(columns=['date'])
        if write_header == 1:
            df_daily = df_row
            write_header = 0
        else:
            df_daily = df_daily.append(df_row)

    with open('salaya_weather.csv','a+') as fd:
        fd.write(df_daily.to_csv(header=write_header_file))
        write_header_file = 0
# Out:
#   0%|                                                                                          | 0/273 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-00210b148053> in <module>
#      42     req = requests.get(url_test)
#      43     js = json.loads(req.text)
# ---> 44     if js['history']['days'] == []:
#      45         print("empty data on",ymd)
#      46         continue
#
# KeyError: 'history'

# %%
import requests
import pandas as pd
from dateutil import parser, rrule
from datetime import datetime, time, date
import time

def getRainfallData(station, day, month, year):
    """
    Function to return a data frame of minute-level weather data for a single Wunderground PWS station.
    
    Args:
        station (string): Station code from the Wunderground website
        day (int): Day of month for which data is requested
        month (int): Month for which data is requested
        year (int): Year for which data is requested
    
    Returns:
        Pandas Dataframe with weather data for specified station and date.
    """
    url = "http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID={station}&day={day}&month={month}&year={year}&graphspan=day&format=1"
    full_url = url.format(station=station, day=day, month=month, year=year)
    # Request data from wunderground data
    response = requests.get(full_url, headers={'User-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
    data = response.text
    # remove the excess <br> from the text data
    data = data.replace('<br>', '')
    # Convert to pandas dataframe (fails if issues with weather station)
    try:
        dataframe = pd.read_csv(io.StringIO(data), index_col=False)
        dataframe['station'] = station
    except Exception as e:
        print("Issue with date: {}-{}-{} for station {}".format(day,month,year, station))
        return None
    return dataframe
    
# Generate a list of all of the dates we want data for
start_date = "2019-01-01"
end_date = "2019-11-01"
start = parser.parse(start_date)
end = parser.parse(end_date)
dates = list(rrule.rrule(rrule.DAILY, dtstart=start, until=end))

# Create a list of stations here to download data for
stations = ["VTBD"]
# Set a backoff time in seconds if a request fails
backoff_time = 10
data = {}

# Gather data for each station in turn and save to CSV.
for station in stations:
    print("Working on {}".format(station))
    data[station] = []
    for date in dates:
        # Print period status update messages
        if date.day % 10 == 0:
            print("Working on date: {} for station {}".format(date, station))
        done = False
        while done == False:
            try:
                weather_data = getRainfallData(station, date.day, date.month, date.year)
                done = True
            except ConnectionError as e:
                # May get rate limited by Wunderground.com, backoff if so.
                print("Got connection error on {}".format(date))
                print("Will retry in {} seconds".format(backoff_time))
                time.sleep(10)
        # Add each processed date to the overall data
        data[station].append(weather_data)
    # Finally combine all of the individual days and output to CSV for analysis.
    pd.concat(data[station]).to_csv("data/{}_weather.csv".format(station))
# Out:
# Working on VTBD
# Issue with date: 1-1-2019 for station VTBD
# Issue with date: 2-1-2019 for station VTBD
# Issue with date: 3-1-2019 for station VTBD
# Issue with date: 4-1-2019 for station VTBD
# Issue with date: 5-1-2019 for station VTBD
# Issue with date: 6-1-2019 for station VTBD
# Issue with date: 7-1-2019 for station VTBD
# Issue with date: 8-1-2019 for station VTBD
# Issue with date: 9-1-2019 for station VTBD
# Working on date: 2019-01-10 00:00:00 for station VTBD
# Issue with date: 10-1-2019 for station VTBD
# Issue with date: 11-1-2019 for station VTBD
# Issue with date: 12-1-2019 for station VTBD
# Issue with date: 13-1-2019 for station VTBD
# Issue with date: 14-1-2019 for station VTBD
# Issue with date: 15-1-2019 for station VTBD
# Issue with date: 16-1-2019 for station VTBD
# Issue with date: 17-1-2019 for station VTBD
# Issue with date: 18-1-2019 for station VTBD
# Issue with date: 19-1-2019 for station VTBD
# Working on date: 2019-01-20 00:00:00 for station VTBD
# Issue with date: 20-1-2019 for station VTBD
# Issue with date: 21-1-2019 for station VTBD
# Issue with date: 22-1-2019 for station VTBD
# Issue with date: 23-1-2019 for station VTBD
# Issue with date: 24-1-2019 for station VTBD
# Issue with date: 25-1-2019 for station VTBD
# Issue with date: 26-1-2019 for station VTBD
# Issue with date: 27-1-2019 for station VTBD
# Issue with date: 28-1-2019 for station VTBD
# Issue with date: 29-1-2019 for station VTBD
# Working on date: 2019-01-30 00:00:00 for station VTBD
# Issue with date: 30-1-2019 for station VTBD
# Issue with date: 31-1-2019 for station VTBD
# Issue with date: 1-2-2019 for station VTBD
# Issue with date: 2-2-2019 for station VTBD
# Issue with date: 3-2-2019 for station VTBD
# Issue with date: 4-2-2019 for station VTBD
# Issue with date: 5-2-2019 for station VTBD
# Issue with date: 6-2-2019 for station VTBD
# Issue with date: 7-2-2019 for station VTBD
# Issue with date: 8-2-2019 for station VTBD
# Issue with date: 9-2-2019 for station VTBD
# Working on date: 2019-02-10 00:00:00 for station VTBD
# Issue with date: 10-2-2019 for station VTBD
# Issue with date: 11-2-2019 for station VTBD
# Issue with date: 12-2-2019 for station VTBD
# Issue with date: 13-2-2019 for station VTBD
# Issue with date: 14-2-2019 for station VTBD
# Issue with date: 15-2-2019 for station VTBD
# Issue with date: 16-2-2019 for station VTBD
# Issue with date: 17-2-2019 for station VTBD
# Issue with date: 18-2-2019 for station VTBD
# Issue with date: 19-2-2019 for station VTBD
# Working on date: 2019-02-20 00:00:00 for station VTBD
# Issue with date: 20-2-2019 for station VTBD
# Issue with date: 21-2-2019 for station VTBD
# Issue with date: 22-2-2019 for station VTBD
# Issue with date: 23-2-2019 for station VTBD
# Issue with date: 24-2-2019 for station VTBD
# Issue with date: 25-2-2019 for station VTBD
# Issue with date: 26-2-2019 for station VTBD
# Issue with date: 27-2-2019 for station VTBD
# Issue with date: 28-2-2019 for station VTBD
# Issue with date: 1-3-2019 for station VTBD
# Issue with date: 2-3-2019 for station VTBD
# Issue with date: 3-3-2019 for station VTBD
# Issue with date: 4-3-2019 for station VTBD
# Issue with date: 5-3-2019 for station VTBD
# Issue with date: 6-3-2019 for station VTBD
# Issue with date: 7-3-2019 for station VTBD
# Issue with date: 8-3-2019 for station VTBD
# Issue with date: 9-3-2019 for station VTBD
# Working on date: 2019-03-10 00:00:00 for station VTBD
# Issue with date: 10-3-2019 for station VTBD
# Issue with date: 11-3-2019 for station VTBD
# Issue with date: 12-3-2019 for station VTBD
# Issue with date: 13-3-2019 for station VTBD
# Issue with date: 14-3-2019 for station VTBD
# Issue with date: 15-3-2019 for station VTBD
# Issue with date: 16-3-2019 for station VTBD
# Issue with date: 17-3-2019 for station VTBD
# Issue with date: 18-3-2019 for station VTBD
# Issue with date: 19-3-2019 for station VTBD
# Working on date: 2019-03-20 00:00:00 for station VTBD
# Issue with date: 20-3-2019 for station VTBD
# Issue with date: 21-3-2019 for station VTBD
# Issue with date: 22-3-2019 for station VTBD
# Issue with date: 23-3-2019 for station VTBD
# Issue with date: 24-3-2019 for station VTBD
# Issue with date: 25-3-2019 for station VTBD
# Issue with date: 26-3-2019 for station VTBD
# Issue with date: 27-3-2019 for station VTBD
# Issue with date: 28-3-2019 for station VTBD
# Issue with date: 29-3-2019 for station VTBD
# Working on date: 2019-03-30 00:00:00 for station VTBD
# Issue with date: 30-3-2019 for station VTBD
# Issue with date: 31-3-2019 for station VTBD
# Issue with date: 1-4-2019 for station VTBD
# Issue with date: 2-4-2019 for station VTBD
# Issue with date: 3-4-2019 for station VTBD
# Issue with date: 4-4-2019 for station VTBD
# Issue with date: 5-4-2019 for station VTBD
# Issue with date: 6-4-2019 for station VTBD
# Issue with date: 7-4-2019 for station VTBD
# Issue with date: 8-4-2019 for station VTBD
# Issue with date: 9-4-2019 for station VTBD
# Working on date: 2019-04-10 00:00:00 for station VTBD
# Issue with date: 10-4-2019 for station VTBD
# Issue with date: 11-4-2019 for station VTBD
# Issue with date: 12-4-2019 for station VTBD
# Issue with date: 13-4-2019 for station VTBD
# Issue with date: 14-4-2019 for station VTBD
# Issue with date: 15-4-2019 for station VTBD
# Issue with date: 16-4-2019 for station VTBD
# Issue with date: 17-4-2019 for station VTBD
# Issue with date: 18-4-2019 for station VTBD
# Issue with date: 19-4-2019 for station VTBD
# Working on date: 2019-04-20 00:00:00 for station VTBD
# Issue with date: 20-4-2019 for station VTBD
# Issue with date: 21-4-2019 for station VTBD
# Issue with date: 22-4-2019 for station VTBD
# Issue with date: 23-4-2019 for station VTBD
# Issue with date: 24-4-2019 for station VTBD
# Issue with date: 25-4-2019 for station VTBD
# Issue with date: 26-4-2019 for station VTBD
# Issue with date: 27-4-2019 for station VTBD
# Issue with date: 28-4-2019 for station VTBD
# Issue with date: 29-4-2019 for station VTBD
# Working on date: 2019-04-30 00:00:00 for station VTBD
# Issue with date: 30-4-2019 for station VTBD
# Issue with date: 1-5-2019 for station VTBD
# Issue with date: 2-5-2019 for station VTBD
# Issue with date: 3-5-2019 for station VTBD
# Issue with date: 4-5-2019 for station VTBD
# Issue with date: 5-5-2019 for station VTBD
# Issue with date: 6-5-2019 for station VTBD
# Issue with date: 7-5-2019 for station VTBD
# Issue with date: 8-5-2019 for station VTBD
# Issue with date: 9-5-2019 for station VTBD
# Working on date: 2019-05-10 00:00:00 for station VTBD
# Issue with date: 10-5-2019 for station VTBD
# Issue with date: 11-5-2019 for station VTBD
# Issue with date: 12-5-2019 for station VTBD
# Issue with date: 13-5-2019 for station VTBD
# Issue with date: 14-5-2019 for station VTBD
# Issue with date: 15-5-2019 for station VTBD
# Issue with date: 16-5-2019 for station VTBD
# Issue with date: 17-5-2019 for station VTBD
# Issue with date: 18-5-2019 for station VTBD
# Issue with date: 19-5-2019 for station VTBD
# Working on date: 2019-05-20 00:00:00 for station VTBD
# Issue with date: 20-5-2019 for station VTBD
# Issue with date: 21-5-2019 for station VTBD
# Issue with date: 22-5-2019 for station VTBD
# Issue with date: 23-5-2019 for station VTBD
# Issue with date: 24-5-2019 for station VTBD
# Issue with date: 25-5-2019 for station VTBD
# Issue with date: 26-5-2019 for station VTBD
# Issue with date: 27-5-2019 for station VTBD
# Issue with date: 28-5-2019 for station VTBD
# Issue with date: 29-5-2019 for station VTBD
# Working on date: 2019-05-30 00:00:00 for station VTBD
# Issue with date: 30-5-2019 for station VTBD
# Issue with date: 31-5-2019 for station VTBD
# Issue with date: 1-6-2019 for station VTBD
# Issue with date: 2-6-2019 for station VTBD
# Issue with date: 3-6-2019 for station VTBD
# Issue with date: 4-6-2019 for station VTBD
# Issue with date: 5-6-2019 for station VTBD
# Issue with date: 6-6-2019 for station VTBD
# Issue with date: 7-6-2019 for station VTBD
# Issue with date: 8-6-2019 for station VTBD
# Issue with date: 9-6-2019 for station VTBD
# Working on date: 2019-06-10 00:00:00 for station VTBD
# Issue with date: 10-6-2019 for station VTBD
# Issue with date: 11-6-2019 for station VTBD
# Issue with date: 12-6-2019 for station VTBD
# Issue with date: 13-6-2019 for station VTBD
# Issue with date: 14-6-2019 for station VTBD
# Issue with date: 15-6-2019 for station VTBD
# Issue with date: 16-6-2019 for station VTBD
# Issue with date: 17-6-2019 for station VTBD
# Issue with date: 18-6-2019 for station VTBD
# Issue with date: 19-6-2019 for station VTBD
# Working on date: 2019-06-20 00:00:00 for station VTBD
# Issue with date: 20-6-2019 for station VTBD
# Issue with date: 21-6-2019 for station VTBD
# Issue with date: 22-6-2019 for station VTBD
# Issue with date: 23-6-2019 for station VTBD
# Issue with date: 24-6-2019 for station VTBD
# Issue with date: 25-6-2019 for station VTBD
# Issue with date: 26-6-2019 for station VTBD
# Issue with date: 27-6-2019 for station VTBD
# Issue with date: 28-6-2019 for station VTBD
# Issue with date: 29-6-2019 for station VTBD
# Working on date: 2019-06-30 00:00:00 for station VTBD
# Issue with date: 30-6-2019 for station VTBD
# Issue with date: 1-7-2019 for station VTBD
# Issue with date: 2-7-2019 for station VTBD
# Issue with date: 3-7-2019 for station VTBD
# Issue with date: 4-7-2019 for station VTBD
# Issue with date: 5-7-2019 for station VTBD
# Issue with date: 6-7-2019 for station VTBD
# Issue with date: 7-7-2019 for station VTBD
# Issue with date: 8-7-2019 for station VTBD
# Issue with date: 9-7-2019 for station VTBD
# Working on date: 2019-07-10 00:00:00 for station VTBD
# Issue with date: 10-7-2019 for station VTBD
# Issue with date: 11-7-2019 for station VTBD
# Issue with date: 12-7-2019 for station VTBD
# Issue with date: 13-7-2019 for station VTBD
# Issue with date: 14-7-2019 for station VTBD
# Issue with date: 15-7-2019 for station VTBD
# Issue with date: 16-7-2019 for station VTBD
# Issue with date: 17-7-2019 for station VTBD
# Issue with date: 18-7-2019 for station VTBD
# Issue with date: 19-7-2019 for station VTBD
# Working on date: 2019-07-20 00:00:00 for station VTBD
# Issue with date: 20-7-2019 for station VTBD
# Issue with date: 21-7-2019 for station VTBD
# Issue with date: 22-7-2019 for station VTBD
# Issue with date: 23-7-2019 for station VTBD
# Issue with date: 24-7-2019 for station VTBD
# Issue with date: 25-7-2019 for station VTBD
# Issue with date: 26-7-2019 for station VTBD
# Issue with date: 27-7-2019 for station VTBD
# Issue with date: 28-7-2019 for station VTBD
# Issue with date: 29-7-2019 for station VTBD
# Working on date: 2019-07-30 00:00:00 for station VTBD
# Issue with date: 30-7-2019 for station VTBD
# Issue with date: 31-7-2019 for station VTBD
# Issue with date: 1-8-2019 for station VTBD
# Issue with date: 2-8-2019 for station VTBD
# Issue with date: 3-8-2019 for station VTBD
# Issue with date: 4-8-2019 for station VTBD
# Issue with date: 5-8-2019 for station VTBD
# Issue with date: 6-8-2019 for station VTBD
# Issue with date: 7-8-2019 for station VTBD
# Issue with date: 8-8-2019 for station VTBD
# Issue with date: 9-8-2019 for station VTBD
# Working on date: 2019-08-10 00:00:00 for station VTBD
# Issue with date: 10-8-2019 for station VTBD
# Issue with date: 11-8-2019 for station VTBD
# Issue with date: 12-8-2019 for station VTBD
# Issue with date: 13-8-2019 for station VTBD
# Issue with date: 14-8-2019 for station VTBD
# Issue with date: 15-8-2019 for station VTBD
# Issue with date: 16-8-2019 for station VTBD
# Issue with date: 17-8-2019 for station VTBD
# Issue with date: 18-8-2019 for station VTBD
# Issue with date: 19-8-2019 for station VTBD
# Working on date: 2019-08-20 00:00:00 for station VTBD
# Issue with date: 20-8-2019 for station VTBD
# Issue with date: 21-8-2019 for station VTBD
# Issue with date: 22-8-2019 for station VTBD
# Issue with date: 23-8-2019 for station VTBD
# Issue with date: 24-8-2019 for station VTBD
# Issue with date: 25-8-2019 for station VTBD
# Issue with date: 26-8-2019 for station VTBD
# Issue with date: 27-8-2019 for station VTBD
# Issue with date: 28-8-2019 for station VTBD
# Issue with date: 29-8-2019 for station VTBD
# Working on date: 2019-08-30 00:00:00 for station VTBD
# Issue with date: 30-8-2019 for station VTBD
# Issue with date: 31-8-2019 for station VTBD
# Issue with date: 1-9-2019 for station VTBD
# Issue with date: 2-9-2019 for station VTBD
# Issue with date: 3-9-2019 for station VTBD
# Issue with date: 4-9-2019 for station VTBD
# Issue with date: 5-9-2019 for station VTBD
# Issue with date: 6-9-2019 for station VTBD
# Issue with date: 7-9-2019 for station VTBD
# Issue with date: 8-9-2019 for station VTBD
# Issue with date: 9-9-2019 for station VTBD
# Working on date: 2019-09-10 00:00:00 for station VTBD
# Issue with date: 10-9-2019 for station VTBD
# Issue with date: 11-9-2019 for station VTBD
# Issue with date: 12-9-2019 for station VTBD
# Issue with date: 13-9-2019 for station VTBD
# Issue with date: 14-9-2019 for station VTBD
# Issue with date: 15-9-2019 for station VTBD
# Issue with date: 16-9-2019 for station VTBD
# Issue with date: 17-9-2019 for station VTBD
# Issue with date: 18-9-2019 for station VTBD
# Issue with date: 19-9-2019 for station VTBD
# Working on date: 2019-09-20 00:00:00 for station VTBD
# Issue with date: 20-9-2019 for station VTBD
# Issue with date: 21-9-2019 for station VTBD
# Issue with date: 22-9-2019 for station VTBD
# Issue with date: 23-9-2019 for station VTBD
# Issue with date: 24-9-2019 for station VTBD
# Issue with date: 25-9-2019 for station VTBD
# Issue with date: 26-9-2019 for station VTBD
# Issue with date: 27-9-2019 for station VTBD
# Issue with date: 28-9-2019 for station VTBD
# Issue with date: 29-9-2019 for station VTBD
# Working on date: 2019-09-30 00:00:00 for station VTBD
# Issue with date: 30-9-2019 for station VTBD
# Issue with date: 1-10-2019 for station VTBD
# Issue with date: 2-10-2019 for station VTBD
# Issue with date: 3-10-2019 for station VTBD
# Issue with date: 4-10-2019 for station VTBD
# Issue with date: 5-10-2019 for station VTBD
# Issue with date: 6-10-2019 for station VTBD
# Issue with date: 7-10-2019 for station VTBD
# Issue with date: 8-10-2019 for station VTBD
# Issue with date: 9-10-2019 for station VTBD
# Working on date: 2019-10-10 00:00:00 for station VTBD
# Issue with date: 10-10-2019 for station VTBD
# Issue with date: 11-10-2019 for station VTBD
# Issue with date: 12-10-2019 for station VTBD
# Issue with date: 13-10-2019 for station VTBD
# Issue with date: 14-10-2019 for station VTBD
# Issue with date: 15-10-2019 for station VTBD
# Issue with date: 16-10-2019 for station VTBD
# Issue with date: 17-10-2019 for station VTBD
# Issue with date: 18-10-2019 for station VTBD
# Issue with date: 19-10-2019 for station VTBD
# Working on date: 2019-10-20 00:00:00 for station VTBD
# Issue with date: 20-10-2019 for station VTBD
# Issue with date: 21-10-2019 for station VTBD
# Issue with date: 22-10-2019 for station VTBD
# Issue with date: 23-10-2019 for station VTBD
# Issue with date: 24-10-2019 for station VTBD
# Issue with date: 25-10-2019 for station VTBD
# Issue with date: 26-10-2019 for station VTBD
# Issue with date: 27-10-2019 for station VTBD
# Issue with date: 28-10-2019 for station VTBD
# Issue with date: 29-10-2019 for station VTBD
# Working on date: 2019-10-30 00:00:00 for station VTBD
# Issue with date: 30-10-2019 for station VTBD
# Issue with date: 31-10-2019 for station VTBD
# Issue with date: 1-11-2019 for station VTBD
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-40a4273cc2b2> in <module>
#      68         data[station].append(weather_data)
#      69     # Finally combine all of the individual days and output to CSV for analysis.
# ---> 70     pd.concat(data[station]).to_csv("data/{}_weather.csv".format(station))
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     320
#     321         if len(objs) == 0:
# --> 322             raise ValueError("All objects passed were None")
#     323
#     324         # consolidate data & figure out what our result ndim is going to be
#
# ValueError: All objects passed were None

# %%
from wwo_hist import retrieve_hist_data
import os
frequency=3
start_date = '11-DEC-2018'
end_date = '11-NOV-2019'
api_key = '2eb5775ee94e4b648e2171109190811'
location_list = ['thailand']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for thailand
#
#
# Currently retrieving data for thailand: from 2018-12-11 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.263578
# Currently retrieving data for thailand: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.947050
# Currently retrieving data for thailand: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:06.287902
# Currently retrieving data for thailand: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.200727
# Currently retrieving data for thailand: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:12.023422
# Currently retrieving data for thailand: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.868155
# Currently retrieving data for thailand: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:16.428067
# Currently retrieving data for thailand: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.033032
# Currently retrieving data for thailand: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:21.275125
# Currently retrieving data for thailand: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:23.219900
# Currently retrieving data for thailand: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:25.507695
# Currently retrieving data for thailand: from 2019-11-01 to 2019-11-11
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-243b6e9556fc> in <module>
#      14                                 location_label = False,
#      15                                 export_csv = True,
# ---> 16                                 store_df = True)
#
# ~\Anaconda3\lib\site-packages\wwo_hist\__init__.py in retrieve_hist_data(api_key, location_list, start_date, end_date, frequency, location_label, export_csv, store_df)
#     104     for location in location_list:
#     105         print('\n\nRetrieving weather data for '+location+'\n\n')
# --> 106         df_this_city = retrieve_this_location(api_key,location,start_date,end_date,frequency)
#     107
#     108         if (location_label == True):
#
# ~\Anaconda3\lib\site-packages\wwo_hist\__init__.py in retrieve_this_location(api_key, location, start_date, end_date, frequency)
#      89         json_page = urllib.request.urlopen(url_page)
#      90         json_data = json.loads(json_page.read().decode())
# ---> 91         data= json_data['data']['weather']
#      92        # call function to extract json object
#      93         df_this_month = extract_monthly_data(data)
#
# KeyError: 'weather'
